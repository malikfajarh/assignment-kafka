# %%
import json
import uuid
import os
import json
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaProducer
from faker import Faker
from time import sleep
import spotify_pb2

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')
kafka_topic = os.getenv('KAFKA_TOPIC_NAME')
kafka_topic_partition = os.getenv('KAFKA_TOPIC_NAME')

# %%
import json
from kafka import KafkaConsumer
from collections import defaultdict

artist_counts = defaultdict(int)

def start_consumer(group_id, client_id, topic_name):
    consumer = KafkaConsumer(
        topic_name,
        group_id=group_id,
        client_id=client_id,
        bootstrap_servers=[f'{kafka_host}:9092'],
        auto_offset_reset='earliest',
        enable_auto_commit=False
    )

    print(f"{client_id} started and subscribed to {topic_name}...")

    try:
        for message in consumer:
            try:

                message_value = message.value.decode('utf-8')
                artist_data = json.loads(message_value)

                artist_name = artist_data.get('artist')
                interaction = artist_data.get('interaction')

                if interaction in ['Play', 'Like']:
                    artist_counts[artist_name] += 1

                sorted_artists = sorted(artist_counts.items(), key=lambda x: x[1], reverse=True)

                print(f"{client_id} Topic: {message.topic}, "
                      f"Partition: {message.partition}, Offset: {message.offset}, "
                      f"Key: {message.key}, Value: {message_value}")
                
                print("-" * 50)
                print("Current Top Artists:")
                for index, (artist, count) in enumerate(sorted_artists, start=1):
                    print(f" {index}. {artist}: {count}")
                print("-" * 50)
            
            except UnicodeDecodeError as e:
                print(f"Error decoding message: {e}. Skipping message.")
            except json.JSONDecodeError as e:
                print(f"Error parsing JSON: {e}. Skipping message.")
    except KeyboardInterrupt:
        print("Shutting down consumer...")
    finally:
        consumer.close()

# %%
import threading

topic_name = kafka_topic

thread1 = threading.Thread(target=start_consumer, args=("consumer_group", "consumer_1", topic_name))
thread1.start()

thread2 = threading.Thread(target=start_consumer, args=("consumer_group", "consumer_2", topic_name))
thread2.start()

thread1.join()
thread2.join()
# Out:
# consumer_1 started and subscribed to spotify...
# consumer_2 started and subscribed to spotify...
# consumer_2 Topic: spotify, Partition: 1, Offset: 697, Key: None, Value: {"track_id": "05daa2bd-2cc8-494e-bf68-c3cc4a05807c", "track_name": "near", "artist": "SZA", "genre": "Country", "popularity": 25, "Duration": 2, "tempo": 82, "explicit": false, "interaction": "Like", "listened_from": "Indonesia", "ts": 1569786104}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 698, Key: None, Value: {"track_id": "7cb40791-91e7-4236-8d86-327b99cd4f6f", "track_name": "water", "artist": "Justin Bieber", "genre": "R&B", "popularity": 36, "Duration": 4, "tempo": 100, "explicit": true, "interaction": "Play", "listened_from": "Indonesia", "ts": 1310970624}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 699, Key: None, Value: {"track_id": "495e8a9c-a90c-4971-bf22-2f654fc3dffb", "track_name": "mean", "artist": "Eminem", "genre": "Country", "popularity": 89, "Duration": 4, "tempo": 176, "explicit": true, "interaction": "Skip", "listened_from": "England", "ts": 808353020}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 700, Key: None, Value: {"track_id": "470dc13f-a056-4fd9-a1f1-c7923c1ade20", "track_name": "up", "artist": "Drake", "genre": "EDM", "popularity": 66, "Duration": 2, "tempo": 19, "explicit": true, "interaction": "Dislike", "listened_from": "Indonesia", "ts": 318824269}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 701, Key: None, Value: {"track_id": "f2dc79dd-9a89-4bfb-a5e5-292b9a28b905", "track_name": "her", "artist": "Justin Bieber", "genre": "EDM", "popularity": 31, "Duration": 5, "tempo": 110, "explicit": true, "interaction": "Stop", "listened_from": "Indonesia", "ts": 422950198}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 702, Key: None, Value: {"track_id": "a519bbbd-c970-46cd-bef6-d7375482ec9c", "track_name": "firm", "artist": "Maroon 5", "genre": "Rock", "popularity": 60, "Duration": 3, "tempo": 19, "explicit": false, "interaction": "Play", "listened_from": "England", "ts": 1348481447}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 703, Key: None, Value: {"track_id": "76bfcc94-9a32-4e9a-aefe-1e17731c15c5", "track_name": "follow", "artist": "The Weekend", "genre": "Soul", "popularity": 44, "Duration": 5, "tempo": 148, "explicit": false, "interaction": "Like", "listened_from": "Brazil", "ts": 1297027370}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 1
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 704, Key: None, Value: {"track_id": "9f4aa0cd-d1c1-462f-8947-e46d47dd8f1a", "track_name": "happen", "artist": "SZA", "genre": "Jazz", "popularity": 96, "Duration": 2, "tempo": 111, "explicit": false, "interaction": "Like", "listened_from": "India", "ts": 1448813966}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 705, Key: None, Value: {"track_id": "e9d32a36-2b1a-4ef3-9086-581e87b9278a", "track_name": "fight", "artist": "Drake", "genre": "Rock", "popularity": 57, "Duration": 5, "tempo": 86, "explicit": true, "interaction": "Skip", "listened_from": "United States", "ts": 126712757}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 706, Key: None, Value: {"track_id": "01c87384-3288-4848-9771-5195eb97c04f", "track_name": "performance", "artist": "Coldplay", "genre": "EDM", "popularity": 48, "Duration": 3, "tempo": 42, "explicit": false, "interaction": "Like", "listened_from": "Singapore", "ts": 839961159}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 707, Key: None, Value: {"track_id": "f051f640-721e-48e8-a08f-c5548955c703", "track_name": "between", "artist": "The Weekend", "genre": "Jazz", "popularity": 72, "Duration": 2, "tempo": 123, "explicit": true, "interaction": "Dislike", "listened_from": "Indonesia", "ts": 844102323}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 708, Key: None, Value: {"track_id": "8c5fbb6c-8fb2-4db9-bd42-e54ec2343f9f", "track_name": "drug", "artist": "The Weekend", "genre": "EDM", "popularity": 69, "Duration": 4, "tempo": 81, "explicit": false, "interaction": "Skip", "listened_from": "India", "ts": 1240317647}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 709, Key: None, Value: {"track_id": "2eb3007b-2cc3-4d45-9027-6b946f0247d7", "track_name": "for", "artist": "John Mayer", "genre": "EDM", "popularity": 93, "Duration": 3, "tempo": 18, "explicit": false, "interaction": "Like", "listened_from": "Italy", "ts": 117597909}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 710, Key: None, Value: {"track_id": "f67dba99-18ee-47a8-831a-ce2f728898bd", "track_name": "our", "artist": "Ed Sheeran", "genre": "EDM", "popularity": 46, "Duration": 2, "tempo": 159, "explicit": true, "interaction": "Like", "listened_from": "Italy", "ts": 599966877}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 711, Key: None, Value: {"track_id": "9cd1d1d5-282b-4b6b-8110-86a11eca835c", "track_name": "see", "artist": "Drake", "genre": "R&B", "popularity": 83, "Duration": 3, "tempo": 66, "explicit": true, "interaction": "Dislike", "listened_from": "Portugal", "ts": 995694269}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 712, Key: None, Value: {"track_id": "7ea69ba4-7b31-4744-9cf3-cbcf3a6a1795", "track_name": "well", "artist": "David Guetta", "genre": "Soul", "popularity": 83, "Duration": 3, "tempo": 25, "explicit": true, "interaction": "Skip", "listened_from": "Singapore", "ts": 347037325}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 713, Key: None, Value: {"track_id": "d61a9b2f-4cf0-4388-a8ed-2dd3035ee0fe", "track_name": "serious", "artist": "Drake", "genre": "Soul", "popularity": 44, "Duration": 3, "tempo": 14, "explicit": false, "interaction": "Play", "listened_from": "Singapore", "ts": 1398876532}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 714, Key: None, Value: {"track_id": "c6fe7a4a-6cd2-4cc6-9ede-ff28ad6e90a6", "track_name": "Congress", "artist": "Eminem", "genre": "EDM", "popularity": 71, "Duration": 4, "tempo": 70, "explicit": true, "interaction": "Dislike", "listened_from": "England", "ts": 355002275}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 715, Key: None, Value: {"track_id": "c13499d4-ef95-4711-aaeb-ccd341dc9789", "track_name": "risk", "artist": "Justin Bieber", "genre": "Jazz", "popularity": 35, "Duration": 3, "tempo": 2, "explicit": false, "interaction": "Stop", "listened_from": "Brazil", "ts": 693367292}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 1
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 716, Key: None, Value: {"track_id": "1de79b5c-09cc-4273-a084-4990764fc106", "track_name": "whose", "artist": "Justin Bieber", "genre": "Jazz", "popularity": 76, "Duration": 2, "tempo": 103, "explicit": false, "interaction": "Play", "listened_from": "Italy", "ts": 580772734}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 2
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 717, Key: None, Value: {"track_id": "1e5c6569-c1a4-444e-83da-4c3a0ad3557c", "track_name": "coach", "artist": "Coldplay", "genre": "Country", "popularity": 57, "Duration": 3, "tempo": 165, "explicit": false, "interaction": "Dislike", "listened_from": "Spain", "ts": 79366224}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 2
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 718, Key: None, Value: {"track_id": "a6ffef09-ff24-4fe3-ab80-347344dca789", "track_name": "wear", "artist": "David Guetta", "genre": "R&B", "popularity": 68, "Duration": 2, "tempo": 58, "explicit": false, "interaction": "Play", "listened_from": "Singapore", "ts": 902581666}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 2
#  3. Maroon 5: 1
#  4. The Weekend: 1
#  5. Coldplay: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 719, Key: None, Value: {"track_id": "265e3ff3-e4b0-47f7-a01d-a5e638437ade", "track_name": "clearly", "artist": "Coldplay", "genre": "Pop", "popularity": 83, "Duration": 5, "tempo": 161, "explicit": false, "interaction": "Play", "listened_from": "Indonesia", "ts": 643287541}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 2
#  3. Coldplay: 2
#  4. Maroon 5: 1
#  5. The Weekend: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 720, Key: None, Value: {"track_id": "d6ac16c6-6de4-438c-87b9-02346cb93d14", "track_name": "information", "artist": "David Guetta", "genre": "Hip hop", "popularity": 58, "Duration": 5, "tempo": 75, "explicit": true, "interaction": "Dislike", "listened_from": "United States", "ts": 1723314076}
# --------------------------------------------------
# Current Top Artists:
#  1. SZA: 2
#  2. Justin Bieber: 2
#  3. Coldplay: 2
#  4. Maroon 5: 1
#  5. The Weekend: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 721, Key: None, Value: {"track_id": "9006d8d5-0048-4781-88b2-c390293fc648", "track_name": "work", "artist": "Justin Bieber", "genre": "Pop", "popularity": 22, "Duration": 5, "tempo": 46, "explicit": true, "interaction": "Like", "listened_from": "Thailand", "ts": 1481943985}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. SZA: 2
#  3. Coldplay: 2
#  4. Maroon 5: 1
#  5. The Weekend: 1
#  6. John Mayer: 1
#  7. Ed Sheeran: 1
#  8. Drake: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 722, Key: None, Value: {"track_id": "55761c8c-284b-43b5-b74d-3b98e9ce94df", "track_name": "happy", "artist": "Drake", "genre": "Soul", "popularity": 63, "Duration": 2, "tempo": 14, "explicit": true, "interaction": "Like", "listened_from": "Portugal", "ts": 1344985776}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. SZA: 2
#  3. Coldplay: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 723, Key: None, Value: {"track_id": "4ceb24fc-1457-4208-b032-2f8d09adeccb", "track_name": "cost", "artist": "David Guetta", "genre": "Hip hop", "popularity": 29, "Duration": 2, "tempo": 49, "explicit": false, "interaction": "Stop", "listened_from": "Spain", "ts": 607512218}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. SZA: 2
#  3. Coldplay: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 724, Key: None, Value: {"track_id": "1bb0940c-97b8-424b-b3ba-813a64641fe3", "track_name": "contain", "artist": "Drake", "genre": "Pop", "popularity": 45, "Duration": 5, "tempo": 141, "explicit": true, "interaction": "Dislike", "listened_from": "Italy", "ts": 1682550966}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. SZA: 2
#  3. Coldplay: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 725, Key: None, Value: {"track_id": "28bc51f0-7d71-4768-85e6-d634ae61b694", "track_name": "return", "artist": "Coldplay", "genre": "Hip hop", "popularity": 21, "Duration": 2, "tempo": 53, "explicit": true, "interaction": "Play", "listened_from": "Italy", "ts": 1556530143}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 726, Key: None, Value: {"track_id": "76f367de-53fb-456a-8ec3-11f4046a1c6d", "track_name": "yourself", "artist": "Justin Bieber", "genre": "Country", "popularity": 57, "Duration": 5, "tempo": 34, "explicit": true, "interaction": "Dislike", "listened_from": "England", "ts": 564247435}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 727, Key: None, Value: {"track_id": "f77a2225-f0d8-4a7a-8bdd-72eaef412aeb", "track_name": "bad", "artist": "The Weekend", "genre": "Soul", "popularity": 46, "Duration": 4, "tempo": 145, "explicit": false, "interaction": "Stop", "listened_from": "Thailand", "ts": 1069685913}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Drake: 2
#  5. Maroon 5: 1
#  6. The Weekend: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 728, Key: None, Value: {"track_id": "ef03f00d-145a-47d2-bd7d-1eaa6cf612f9", "track_name": "game", "artist": "The Weekend", "genre": "Hip hop", "popularity": 65, "Duration": 4, "tempo": 133, "explicit": true, "interaction": "Like", "listened_from": "Spain", "ts": 288001937}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. The Weekend: 2
#  5. Drake: 2
#  6. Maroon 5: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 729, Key: None, Value: {"track_id": "b39f7f02-ac00-4271-a150-8d3eb3524848", "track_name": "need", "artist": "Taylor Swift", "genre": "EDM", "popularity": 57, "Duration": 4, "tempo": 108, "explicit": false, "interaction": "Play", "listened_from": "India", "ts": 153224076}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. The Weekend: 2
#  5. Drake: 2
#  6. Maroon 5: 1
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 730, Key: None, Value: {"track_id": "765e7ae2-f9b2-4086-b490-b0ee25c15abd", "track_name": "read", "artist": "Maroon 5", "genre": "Hip hop", "popularity": 67, "Duration": 4, "tempo": 113, "explicit": true, "interaction": "Like", "listened_from": "Brazil", "ts": 264081475}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 731, Key: None, Value: {"track_id": "2af9a952-b13c-4435-b2c3-6aebdd00f993", "track_name": "wrong", "artist": "David Guetta", "genre": "Jazz", "popularity": 97, "Duration": 2, "tempo": 156, "explicit": true, "interaction": "Dislike", "listened_from": "Portugal", "ts": 270175925}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 732, Key: None, Value: {"track_id": "2c6e5da2-24b0-4325-9025-dc4d09974d69", "track_name": "enter", "artist": "Lady Gaga", "genre": "Country", "popularity": 60, "Duration": 2, "tempo": 156, "explicit": false, "interaction": "Stop", "listened_from": "Brazil", "ts": 20849139}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 733, Key: None, Value: {"track_id": "10647ed2-744d-41e9-9470-3348cf66d2f3", "track_name": "job", "artist": "John Mayer", "genre": "EDM", "popularity": 36, "Duration": 2, "tempo": 138, "explicit": false, "interaction": "Stop", "listened_from": "Japan", "ts": 1641439412}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 734, Key: None, Value: {"track_id": "f7d62891-c193-4c63-bb3f-b19df9d7af01", "track_name": "scene", "artist": "SZA", "genre": "Soul", "popularity": 87, "Duration": 3, "tempo": 52, "explicit": false, "interaction": "Skip", "listened_from": "United States", "ts": 448798614}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 735, Key: None, Value: {"track_id": "56336032-e57f-4948-b0eb-1f1b91a0e7ab", "track_name": "because", "artist": "Taylor Swift", "genre": "Pop", "popularity": 95, "Duration": 2, "tempo": 61, "explicit": false, "interaction": "Dislike", "listened_from": "Singapore", "ts": 798310853}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. SZA: 2
#  4. Maroon 5: 2
#  5. The Weekend: 2
#  6. Drake: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 736, Key: None, Value: {"track_id": "68911278-66d9-4bc9-bd73-b1baa6ef9469", "track_name": "make", "artist": "Drake", "genre": "R&B", "popularity": 67, "Duration": 5, "tempo": 70, "explicit": false, "interaction": "Play", "listened_from": "United States", "ts": 975775000}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 737, Key: None, Value: {"track_id": "25e3c2fd-cff2-4f59-b643-d3890cfe64a0", "track_name": "economic", "artist": "David Guetta", "genre": "Pop", "popularity": 61, "Duration": 4, "tempo": 133, "explicit": true, "interaction": "Skip", "listened_from": "Portugal", "ts": 1407462474}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 738, Key: None, Value: {"track_id": "2986b060-3f8d-4b63-9a14-f0d788014a76", "track_name": "many", "artist": "John Mayer", "genre": "Country", "popularity": 28, "Duration": 4, "tempo": 156, "explicit": true, "interaction": "Skip", "listened_from": "Singapore", "ts": 1620320483}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. John Mayer: 1
#  8. Ed Sheeran: 1
#  9. David Guetta: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 739, Key: None, Value: {"track_id": "c81b3c89-f754-4876-b09e-d7a0d8e286c0", "track_name": "long", "artist": "David Guetta", "genre": "Hip hop", "popularity": 75, "Duration": 4, "tempo": 141, "explicit": true, "interaction": "Play", "listened_from": "Spain", "ts": 1577561283}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 740, Key: None, Value: {"track_id": "e33f5297-61a6-490b-b1f2-5b913e386d64", "track_name": "father", "artist": "SZA", "genre": "Pop", "popularity": 64, "Duration": 3, "tempo": 94, "explicit": false, "interaction": "Dislike", "listened_from": "Thailand", "ts": 685040344}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 741, Key: None, Value: {"track_id": "d12d8e39-d674-44ff-ab74-8958a61f67b5", "track_name": "politics", "artist": "Justin Bieber", "genre": "EDM", "popularity": 69, "Duration": 5, "tempo": 21, "explicit": false, "interaction": "Stop", "listened_from": "England", "ts": 113694962}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 742, Key: None, Value: {"track_id": "a3172660-8c08-40c3-ac9f-de43a2b515d5", "track_name": "control", "artist": "Eminem", "genre": "EDM", "popularity": 26, "Duration": 5, "tempo": 90, "explicit": true, "interaction": "Skip", "listened_from": "Indonesia", "ts": 151760373}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 743, Key: None, Value: {"track_id": "2b04d375-2b90-49e7-b165-a53da2a1a5ac", "track_name": "score", "artist": "Lady Gaga", "genre": "Soul", "popularity": 70, "Duration": 4, "tempo": 43, "explicit": false, "interaction": "Like", "listened_from": "Spain", "ts": 578591146}
# --------------------------------------------------
# Current Top Artists:
#  1. Justin Bieber: 3
#  2. Coldplay: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
#  11. Lady Gaga: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 744, Key: None, Value: {"track_id": "6d48ab9d-6b5d-4d70-b3c6-1ca9d5dcf9c9", "track_name": "me", "artist": "Coldplay", "genre": "R&B", "popularity": 45, "Duration": 5, "tempo": 33, "explicit": true, "interaction": "Like", "listened_from": "Brazil", "ts": 982908814}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. John Mayer: 1
#  9. Ed Sheeran: 1
#  10. Taylor Swift: 1
#  11. Lady Gaga: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 745, Key: None, Value: {"track_id": "00011027-c2fd-4ada-b2bf-f13ed0d09863", "track_name": "talk", "artist": "Lady Gaga", "genre": "EDM", "popularity": 46, "Duration": 5, "tempo": 118, "explicit": true, "interaction": "Like", "listened_from": "Portugal", "ts": 1694687872}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. Lady Gaga: 2
#  9. John Mayer: 1
#  10. Ed Sheeran: 1
#  11. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 746, Key: None, Value: {"track_id": "4fd15ea1-9bca-4b6b-8d54-e5faf0c6fe59", "track_name": "address", "artist": "Justin Bieber", "genre": "R&B", "popularity": 38, "Duration": 5, "tempo": 42, "explicit": false, "interaction": "Dislike", "listened_from": "India", "ts": 1260417733}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. Lady Gaga: 2
#  9. John Mayer: 1
#  10. Ed Sheeran: 1
#  11. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 747, Key: None, Value: {"track_id": "3d47c9de-92a8-402d-a4d1-c95e9bf2a08c", "track_name": "director", "artist": "Taylor Swift", "genre": "Hip hop", "popularity": 46, "Duration": 2, "tempo": 14, "explicit": false, "interaction": "Stop", "listened_from": "Spain", "ts": 1112069648}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. Lady Gaga: 2
#  9. John Mayer: 1
#  10. Ed Sheeran: 1
#  11. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 748, Key: None, Value: {"track_id": "eb65bcd5-1eb3-4f67-aeb7-ac9376cdf000", "track_name": "commercial", "artist": "Coldplay", "genre": "R&B", "popularity": 51, "Duration": 3, "tempo": 151, "explicit": false, "interaction": "Stop", "listened_from": "Italy", "ts": 715800296}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. Lady Gaga: 2
#  9. John Mayer: 1
#  10. Ed Sheeran: 1
#  11. Taylor Swift: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 749, Key: None, Value: {"track_id": "e04a89f9-89a7-41a9-a347-73eca173d33c", "track_name": "trip", "artist": "Taylor Swift", "genre": "Rock", "popularity": 52, "Duration": 2, "tempo": 88, "explicit": true, "interaction": "Like", "listened_from": "Spain", "ts": 582663609}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. SZA: 2
#  5. Maroon 5: 2
#  6. The Weekend: 2
#  7. David Guetta: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 750, Key: None, Value: {"track_id": "f1ace0c4-9312-4add-bda5-66026503d01e", "track_name": "thing", "artist": "David Guetta", "genre": "EDM", "popularity": 56, "Duration": 5, "tempo": 176, "explicit": false, "interaction": "Like", "listened_from": "Italy", "ts": 1075898805}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. Drake: 3
#  4. David Guetta: 3
#  5. SZA: 2
#  6. Maroon 5: 2
#  7. The Weekend: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 751, Key: None, Value: {"track_id": "2594b544-f479-45f6-bbbe-fc1884bc5c5e", "track_name": "action", "artist": "The Weekend", "genre": "Hip hop", "popularity": 71, "Duration": 2, "tempo": 5, "explicit": false, "interaction": "Play", "listened_from": "United States", "ts": 502328219}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. The Weekend: 3
#  4. Drake: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 752, Key: None, Value: {"track_id": "4eb51355-b47e-48d0-9f74-77df6a9cba6c", "track_name": "science", "artist": "Justin Bieber", "genre": "R&B", "popularity": 72, "Duration": 5, "tempo": 117, "explicit": false, "interaction": "Skip", "listened_from": "Germany", "ts": 1566201630}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Justin Bieber: 3
#  3. The Weekend: 3
#  4. Drake: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 753, Key: None, Value: {"track_id": "9e6de9b2-0e94-4b9f-89f0-e0d83983a454", "track_name": "surface", "artist": "Drake", "genre": "Hip hop", "popularity": 68, "Duration": 4, "tempo": 22, "explicit": false, "interaction": "Like", "listened_from": "Brazil", "ts": 612721123}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 754, Key: None, Value: {"track_id": "2c9d3888-0b10-4742-bb32-533df809cfe8", "track_name": "wife", "artist": "Maroon 5", "genre": "EDM", "popularity": 36, "Duration": 2, "tempo": 118, "explicit": true, "interaction": "Skip", "listened_from": "Thailand", "ts": 62351986}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 755, Key: None, Value: {"track_id": "81851146-8488-4ce8-a213-b66bc9cf2494", "track_name": "author", "artist": "Lady Gaga", "genre": "Jazz", "popularity": 55, "Duration": 4, "tempo": 130, "explicit": true, "interaction": "Skip", "listened_from": "Singapore", "ts": 932865662}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 756, Key: None, Value: {"track_id": "e56aeca9-a2cc-4bf4-a55f-b5647696ed1e", "track_name": "clearly", "artist": "David Guetta", "genre": "R&B", "popularity": 53, "Duration": 4, "tempo": 51, "explicit": true, "interaction": "Skip", "listened_from": "Indonesia", "ts": 1383163246}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 4
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 757, Key: None, Value: {"track_id": "6349bd31-4674-4019-9a78-aa9f63ef48a7", "track_name": "show", "artist": "Coldplay", "genre": "Country", "popularity": 71, "Duration": 3, "tempo": 67, "explicit": false, "interaction": "Like", "listened_from": "Spain", "ts": 1292392191}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 758, Key: None, Value: {"track_id": "292a6ffe-78d4-4b16-aa04-4e7309c36ded", "track_name": "several", "artist": "Maroon 5", "genre": "Jazz", "popularity": 69, "Duration": 5, "tempo": 129, "explicit": false, "interaction": "Dislike", "listened_from": "Portugal", "ts": 391646904}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 759, Key: None, Value: {"track_id": "9a19869b-7eb3-4b40-89c8-004a923502db", "track_name": "point", "artist": "Taylor Swift", "genre": "R&B", "popularity": 46, "Duration": 3, "tempo": 46, "explicit": false, "interaction": "Stop", "listened_from": "Thailand", "ts": 961522096}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Taylor Swift: 2
#  9. Lady Gaga: 2
#  10. John Mayer: 1
#  11. Ed Sheeran: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 760, Key: None, Value: {"track_id": "cfa19c61-d8d7-4525-8d64-9a2e27020176", "track_name": "for", "artist": "Ed Sheeran", "genre": "Hip hop", "popularity": 31, "Duration": 3, "tempo": 165, "explicit": true, "interaction": "Play", "listened_from": "Spain", "ts": 302448144}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. SZA: 2
#  7. Maroon 5: 2
#  8. Ed Sheeran: 2
#  9. Taylor Swift: 2
#  10. Lady Gaga: 2
#  11. John Mayer: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 761, Key: None, Value: {"track_id": "9636a4d1-165c-41ee-a08c-a7c4c6641e92", "track_name": "its", "artist": "Lady Gaga", "genre": "Soul", "popularity": 27, "Duration": 5, "tempo": 21, "explicit": true, "interaction": "Play", "listened_from": "India", "ts": 258608233}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. Lady Gaga: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 762, Key: None, Value: {"track_id": "775b0f1d-8aac-4186-9b39-5f2ecaad0de4", "track_name": "nor", "artist": "Eminem", "genre": "Rock", "popularity": 24, "Duration": 2, "tempo": 129, "explicit": false, "interaction": "Like", "listened_from": "Italy", "ts": 214590731}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. Lady Gaga: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 763, Key: None, Value: {"track_id": "48ab60a3-adaf-4eb1-8fb5-31afdb750011", "track_name": "turn", "artist": "Maroon 5", "genre": "EDM", "popularity": 48, "Duration": 3, "tempo": 22, "explicit": false, "interaction": "Skip", "listened_from": "England", "ts": 163536883}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. Lady Gaga: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 764, Key: None, Value: {"track_id": "2638ef95-7e37-45b8-9424-28475af493cf", "track_name": "they", "artist": "David Guetta", "genre": "R&B", "popularity": 62, "Duration": 2, "tempo": 142, "explicit": true, "interaction": "Stop", "listened_from": "Spain", "ts": 305008018}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. Lady Gaga: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 765, Key: None, Value: {"track_id": "80164870-e358-4b38-bdf7-b6c50fc13d90", "track_name": "writer", "artist": "Eminem", "genre": "Jazz", "popularity": 47, "Duration": 3, "tempo": 163, "explicit": true, "interaction": "Dislike", "listened_from": "England", "ts": 844408469}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Justin Bieber: 3
#  4. The Weekend: 3
#  5. David Guetta: 3
#  6. Lady Gaga: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 766, Key: None, Value: {"track_id": "9380a9a1-b381-411c-bd6c-0b66b40b9130", "track_name": "skill", "artist": "Lady Gaga", "genre": "Hip hop", "popularity": 71, "Duration": 4, "tempo": 173, "explicit": false, "interaction": "Like", "listened_from": "Germany", "ts": 838352584}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 767, Key: None, Value: {"track_id": "d0d171ef-e23c-4f1a-a316-c74a934597f5", "track_name": "out", "artist": "Taylor Swift", "genre": "Jazz", "popularity": 41, "Duration": 3, "tempo": 75, "explicit": false, "interaction": "Stop", "listened_from": "Singapore", "ts": 1494064641}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 768, Key: None, Value: {"track_id": "af71dca0-4d70-48e6-b136-5252a34fe65e", "track_name": "but", "artist": "Drake", "genre": "EDM", "popularity": 96, "Duration": 2, "tempo": 7, "explicit": false, "interaction": "Skip", "listened_from": "Japan", "ts": 1072883407}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 5
#  2. Drake: 4
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 769, Key: None, Value: {"track_id": "71026239-ef09-4b9d-baa0-bdee67f19785", "track_name": "poor", "artist": "Coldplay", "genre": "R&B", "popularity": 78, "Duration": 4, "tempo": 6, "explicit": false, "interaction": "Like", "listened_from": "Japan", "ts": 1566547396}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 6
#  2. Drake: 4
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 770, Key: None, Value: {"track_id": "bb6ab370-6188-4265-8019-2741b7e55bcd", "track_name": "shake", "artist": "Coldplay", "genre": "Soul", "popularity": 47, "Duration": 3, "tempo": 172, "explicit": false, "interaction": "Play", "listened_from": "England", "ts": 847244300}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 4
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 771, Key: None, Value: {"track_id": "a95f1fda-8c0d-407e-9895-b7deaa4bc1ef", "track_name": "music", "artist": "Drake", "genre": "Hip hop", "popularity": 53, "Duration": 5, "tempo": 51, "explicit": false, "interaction": "Like", "listened_from": "Brazil", "ts": 338491116}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 5
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 772, Key: None, Value: {"track_id": "982934ee-6fa0-4e4d-b5a8-876329eeb366", "track_name": "create", "artist": "Eminem", "genre": "Pop", "popularity": 35, "Duration": 4, "tempo": 159, "explicit": false, "interaction": "Stop", "listened_from": "Singapore", "ts": 679296582}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 5
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 773, Key: None, Value: {"track_id": "eb220f6a-802a-4dcf-a74a-bc6f7e4db107", "track_name": "similar", "artist": "David Guetta", "genre": "Pop", "popularity": 78, "Duration": 5, "tempo": 15, "explicit": false, "interaction": "Stop", "listened_from": "Thailand", "ts": 38213624}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 5
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 774, Key: None, Value: {"track_id": "31f8c6db-97aa-4d83-831f-2917f4e5646a", "track_name": "seem", "artist": "Maroon 5", "genre": "EDM", "popularity": 27, "Duration": 2, "tempo": 169, "explicit": false, "interaction": "Dislike", "listened_from": "Japan", "ts": 1683669292}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 5
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 775, Key: None, Value: {"track_id": "229204fc-4934-4e8a-aa74-ec4e1a0a1d45", "track_name": "fall", "artist": "SZA", "genre": "Pop", "popularity": 30, "Duration": 5, "tempo": 108, "explicit": false, "interaction": "Skip", "listened_from": "Singapore", "ts": 1039468052}
# --------------------------------------------------
# Current Top Artists:
#  1. Coldplay: 7
#  2. Drake: 5
#  3. Lady Gaga: 4
#  4. Justin Bieber: 3
#  5. The Weekend: 3
#  6. David Guetta: 3
#  7. SZA: 2
#  8. Maroon 5: 2
#  9. Ed Sheeran: 2
#  10. Taylor Swift: 2
#  11. John Mayer: 1
#  12. Eminem: 1
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 776, Key: None, Value: {"track_id": "5dc7056e-a12b-4cef-bccc-599f54defc05", "track_name": "recently", "artist": "Eminem", "genre": "R&B", "popularity": 96, "Duration": 4, "tempo": 68, "explicit": true, "interaction": "Stop", "listened_from": "United States", "ts": 1227013679}
# ...
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 29
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1563, Key: None, Value: {"track_id": "e6309e5d-e701-440a-b7e7-a2bf2ff1da4d", "track_name": "simply", "artist": "Eminem", "genre": "R&B", "popularity": 92, "Duration": 2, "tempo": 20, "explicit": true, "interaction": "Dislike", "listened_from": "Indonesia", "ts": 1101064707}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 29
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1564, Key: None, Value: {"track_id": "cd536655-4650-4102-a83c-71b599fb0d70", "track_name": "dinner", "artist": "John Mayer", "genre": "R&B", "popularity": 85, "Duration": 2, "tempo": 140, "explicit": false, "interaction": "Skip", "listened_from": "England", "ts": 1344314224}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 29
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1565, Key: None, Value: {"track_id": "3b8985ad-cecb-471d-8acd-9777fc427552", "track_name": "health", "artist": "David Guetta", "genre": "Rock", "popularity": 80, "Duration": 5, "tempo": 149, "explicit": false, "interaction": "Skip", "listened_from": "Germany", "ts": 234871159}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 29
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1566, Key: None, Value: {"track_id": "47acb570-8f45-4814-bebe-5623bada9bcb", "track_name": "hospital", "artist": "David Guetta", "genre": "EDM", "popularity": 52, "Duration": 4, "tempo": 70, "explicit": true, "interaction": "Play", "listened_from": "Japan", "ts": 865786503}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1567, Key: None, Value: {"track_id": "c748281a-4fc9-459f-928d-05b2f0a9b01b", "track_name": "address", "artist": "Justin Bieber", "genre": "Soul", "popularity": 27, "Duration": 2, "tempo": 70, "explicit": false, "interaction": "Stop", "listened_from": "Italy", "ts": 21996080}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. Ed Sheeran: 31
#  3. John Mayer: 30
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1568, Key: None, Value: {"track_id": "c07aaa2d-f165-4bbc-8275-16b51f853449", "track_name": "fund", "artist": "John Mayer", "genre": "EDM", "popularity": 84, "Duration": 5, "tempo": 62, "explicit": false, "interaction": "Like", "listened_from": "Spain", "ts": 265607543}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1569, Key: None, Value: {"track_id": "bfbbd9ac-9a83-4903-ae2b-c98e32a8352e", "track_name": "test", "artist": "SZA", "genre": "Soul", "popularity": 76, "Duration": 5, "tempo": 114, "explicit": false, "interaction": "Dislike", "listened_from": "Japan", "ts": 716026355}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 25
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1570, Key: None, Value: {"track_id": "6b7311f7-1ee2-45ac-ae1f-3f4e43ab46d6", "track_name": "fight", "artist": "SZA", "genre": "Soul", "popularity": 29, "Duration": 3, "tempo": 24, "explicit": true, "interaction": "Like", "listened_from": "Portugal", "ts": 1440989382}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 20
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1481, Key: None, Value: {"track_id": "fc622016-1d69-4917-8417-2daae9fe1cb5", "track_name": "success", "artist": "Maroon 5", "genre": "Jazz", "popularity": 90, "Duration": 4, "tempo": 123, "explicit": true, "interaction": "Like", "listened_from": "United States", "ts": 1503854272}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1482, Key: None, Value: {"track_id": "ca8cd20f-da1e-4461-85ab-d35a6ade9b7b", "track_name": "tough", "artist": "SZA", "genre": "Soul", "popularity": 25, "Duration": 5, "tempo": 59, "explicit": false, "interaction": "Skip", "listened_from": "Spain", "ts": 311808777}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1571, Key: None, Value: {"track_id": "c536e914-9b5a-4537-9cf4-cb41507b8a51", "track_name": "dog", "artist": "Ed Sheeran", "genre": "R&B", "popularity": 80, "Duration": 3, "tempo": 31, "explicit": false, "interaction": "Skip", "listened_from": "Japan", "ts": 312301448}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1483, Key: None, Value: {"track_id": "59c68bc0-db93-404b-b026-84a787d8f7b6", "track_name": "over", "artist": "Ed Sheeran", "genre": "Rock", "popularity": 55, "Duration": 5, "tempo": 5, "explicit": true, "interaction": "Dislike", "listened_from": "England", "ts": 439761677}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1572, Key: None, Value: {"track_id": "1d69d954-339d-4038-ad93-15946be7e1ef", "track_name": "threat", "artist": "Drake", "genre": "Hip hop", "popularity": 42, "Duration": 2, "tempo": 60, "explicit": false, "interaction": "Skip", "listened_from": "Italy", "ts": 217664166}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1484, Key: None, Value: {"track_id": "285b909f-5089-4469-aeb1-44bfe9c247c0", "track_name": "event", "artist": "Eminem", "genre": "Rock", "popularity": 72, "Duration": 5, "tempo": 11, "explicit": true, "interaction": "Skip", "listened_from": "England", "ts": 1260749567}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 31
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1573, Key: None, Value: {"track_id": "6648147c-0e2f-40be-a189-729d99f1df36", "track_name": "prove", "artist": "John Mayer", "genre": "EDM", "popularity": 22, "Duration": 5, "tempo": 123, "explicit": false, "interaction": "Like", "listened_from": "Brazil", "ts": 336802161}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 31
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1485, Key: None, Value: {"track_id": "4d1ec6ca-8a19-47a2-a5d7-13f241a05ebf", "track_name": "southern", "artist": "Ed Sheeran", "genre": "Jazz", "popularity": 77, "Duration": 4, "tempo": 168, "explicit": false, "interaction": "Like", "listened_from": "United States", "ts": 1614202524}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1574, Key: None, Value: {"track_id": "311b4dc8-d060-44f9-b078-1c17a8396170", "track_name": "research", "artist": "Maroon 5", "genre": "Pop", "popularity": 79, "Duration": 3, "tempo": 67, "explicit": true, "interaction": "Stop", "listened_from": "Germany", "ts": 717186478}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1575, Key: None, Value: {"track_id": "6de828b9-e52f-4bb2-ac80-13ea3d21cc68", "track_name": "collection", "artist": "SZA", "genre": "R&B", "popularity": 50, "Duration": 4, "tempo": 78, "explicit": true, "interaction": "Stop", "listened_from": "Singapore", "ts": 123580351}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1486, Key: None, Value: {"track_id": "8d04c6f0-0630-4ca1-81d3-e782e931f6f7", "track_name": "cup", "artist": "Coldplay", "genre": "Hip hop", "popularity": 90, "Duration": 2, "tempo": 130, "explicit": false, "interaction": "Dislike", "listened_from": "Italy", "ts": 1441755638}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1576, Key: None, Value: {"track_id": "5163cbcc-0da2-41bf-bec7-433d6c4ff109", "track_name": "similar", "artist": "David Guetta", "genre": "Country", "popularity": 93, "Duration": 2, "tempo": 16, "explicit": true, "interaction": "Stop", "listened_from": "Germany", "ts": 194911487}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 32
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_1 Topic: spotify, Partition: 0, Offset: 1487, Key: None, Value: {"track_id": "ddc36c42-fae5-490b-9779-b46427844914", "track_name": "push", "artist": "John Mayer", "genre": "Hip hop", "popularity": 68, "Duration": 5, "tempo": 34, "explicit": false, "interaction": "Like", "listened_from": "Indonesia", "ts": 838424881}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 33
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# consumer_2 Topic: spotify, Partition: 1, Offset: 1577, Key: None, Value: {"track_id": "6c0d972a-cce3-4bb3-89fd-86af5eafe884", "track_name": "help", "artist": "Maroon 5", "genre": "Rock", "popularity": 49, "Duration": 2, "tempo": 51, "explicit": true, "interaction": "Skip", "listened_from": "Japan", "ts": 280301978}
# --------------------------------------------------
# Current Top Artists:
#  1. The Weekend: 39
#  2. John Mayer: 33
#  3. Ed Sheeran: 32
#  4. Drake: 30
#  5. David Guetta: 30
#  6. Justin Bieber: 27
#  7. SZA: 26
#  8. Coldplay: 25
#  9. Eminem: 22
#  10. Maroon 5: 21
#  11. Lady Gaga: 20
#  12. Taylor Swift: 17
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       8 thread2 = threading.Thread(target=start_consumer, args=("consumer_group", "consumer_2", topic_name))
#       9 thread2.start()
# ---> 11 thread1.join()
#      12 thread2.join()
#
# File /opt/conda/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/conda/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
# protobuf error parsing type 'Spotify'

# from kafka import KafkaConsumer
# from collections import defaultdict
# import spotify_pb2 

# artist_counts = defaultdict(int)
# spotify = spotify_pb2.Spotify()

# def start_consumer(group_id, client_id, topic_name):
#     consumer = KafkaConsumer(
#         topic_name,
#         group_id=group_id,
#         client_id=client_id,
#         bootstrap_servers=[f'{kafka_host}:9092'],
#         value_deserializer=lambda v: spotify_pb2.Spotify.FromString(v),  # Deserialize Protobuf
#         auto_offset_reset='earliest',
#         enable_auto_commit=False
#     )

#     print(f"{client_id} started and subscribed to {topic_name}...")
    
#     try:
#         for message in consumer:
#             print(f"Raw message value: {message.value}")
#              
#             message_value = message.value.decode('utf-8')
#
#             artist_name = message_value.artist
#             interaction = message_value.interaction
            
#             if interaction in ['Play', 'Like']:
#                 artist_counts[artist_name] += 1
            
#             sorted_artists = sorted(artist_counts.items(), key=lambda x: x[1], reverse=True)
            
#             print(f"{client_id} Topic: {message.topic}, "
#                   f"Partition: {message.partition}, Offset: {message.offset}, "
#                   f"Key: {message.key}, Value: {message_value}")
#             print("-" * 50)
#             print("Current Top Artists:")
#             for index, (artist, count) in enumerate(sorted_artists, start=1):
#                 print(f" {index}. {artist}: {count}")
#             print("-" * 50)
            
#     except KeyboardInterrupt:
#         print("Shutting down consumer...")
#     finally:
#         consumer.close()
